# %% [markdown]
# # Using Virtual Environments with Python 3's *venv*

# %% [markdown]
# ## Setup

# %%
import os
import pathlib
from IPython.display import Image

home = os.getenv('HOME')
suffix = '/Projects/data-science-blog'
os.chdir(home + suffix)

# %%
Image("images/novenv_syspath.png")

# %% [markdown]
# ## 1. Make your virtual environment

# %% [markdown]
# ```
# $ cd Projects/my-project
# $ python3 -m venv venv
# $ ls
# ```

# %%
Image("images/make_venv.png")

# %% [markdown]
# ## 2. Activate your virtual environment

# %% [markdown]
# ```bash
# $ source venv/bin/activate
# $ which python
# ```

# %%
Image("images/activate_venv.png")

# %% [markdown]
# ## 3. Verify Python Path

# %% [markdown]
# ```bash
# $ python
# ```
#
# ```python
# >>> from sys import path
# >>> print('\n'.join(path))
# ```

# %%
Image("images/venv_syspath.png")

# %% [markdown]
# ## 4. Install Package with Pip

# %%
Image("images/pip_install_venv.png")
